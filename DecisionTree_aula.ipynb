# %% [markdown]
# Implementação de algumas bibliotecas, leitura de um arquivo e criação de um dataframe

# %%
import numpy as np
import pandas as pd
from sklearn import tree

input_file = "PastHires.csv"
df = pd.read_csv(input_file, header = 0)

# %%
df.head()
# Out:
#    Years Experience Employed?  Previous employers Level of Education  \
# 0                10         Y                   4                 BS
# 1                 0         N                   0                 BS
# 2                 7         N                   6                 BS
# 3                 2         Y                   1                 MS
# 4                20         N                   2                PhD
#
#   Top-tier school Interned Hired
# 0               N        N     Y
# 1               Y        Y     Y
# 2               N        N     N
# 3               Y        N     Y
# 4               Y        N     N

# %% [markdown]
# Criou um dicionario que 0 significa não e 1 significa sim,

# %%
d = {'Y': 1, 'N': 0}
df['Hired'] = df['Hired'].map(d)
df['Employed?'] = df['Employed?'].map(d)
df['Top-tier school'] = df['Top-tier school'].map(d)
df['Interned'] = df['Interned'].map(d)
d = {'BS': 0, 'MS': 1, 'PhD': 2}
df['Level of Education'] = df['Level of Education'].map(d)
df.head()
# Out:
#    Years Experience  Employed?  Previous employers  Level of Education  \
# 0                10          1                   4                   0
# 1                 0          0                   0                   0
# 2                 7          0                   6                   0
# 3                 2          1                   1                   1
# 4                20          0                   2                   2
#
#    Top-tier school  Interned  Hired
# 0                0         0      1
# 1                1         1      1
# 2                0         0      0
# 3                1         0      1
# 4                1         0      0

# %%
features = list(df.columns[:6])
features
# Out:
# ['Years Experience',
#  'Employed?',
#  'Previous employers',
#  'Level of Education',
#  'Top-tier school',
#  'Interned']

# %%
y = df["Hired"]
X = df[features]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X,y)

# %%
from IPython.display import Image  
from io import StringIO  
import pydotplus
from sklearn.tree import export_graphviz

# Supondo que clf seja seu classificador de árvore de decisão e features seja a lista de nomes das características

dot_data = StringIO()  
export_graphviz(clf, out_file=dot_data,  
                feature_names=features,  
                filled=True, rounded=True,  
                special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X, y)

#Predict employment of an employed 10-year veteran
print (clf.predict([[10, 1, 4, 0, 0, 0]]))
#...and an unemployed 10-year veteran
print (clf.predict([[10, 0, 4, 0, 0, 0]]))
# Out:
# [1]
# [0]
# C:\Users\lshun\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\lshun\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
